# %% [markdown]
# ## Company Values
# I will be working on NASDAQ TOP Companies with the most Values in the Stock Market from 2010 - 20220

# %% [markdown]
# ## Problem Statement
# Investors and analysts need to understand stock market trends, price movements, and trading volumes for major companies like
# Amazon, Apple, Google, Microsoft, and Tesla. This dataset helps identify patterns, volatility, and key market behaviors
# from mid-2010 to mid-2020. By analyzing stock price changes, volume fluctuations, and historical trends, users can make
# informed investment decisions, detect market opportunities, and assess potential risks.

# %% [markdown]
# ## Data Importation
# Data importation is a process of bringing in your dataset into your Notebook to enable you have a better Overview of the
# data you will be working with and also help you make your analysis and provide useful insights

# %%
import pandas as pd

Company_data = pd.read_csv('CompanyValues.csv')
Company_name = pd.read_csv('Company.csv')

# %%
Company_data
# Out:
#       ticker_symbol    day_date  close_value    volume  open_value  \
# 0              AAPL  2020-05-29       317.94  38399530      319.25
# 1              AAPL  2020-05-28       318.25  33449100      316.77
# 2              AAPL  2020-05-27       318.11  28236270      316.14
# 3              AAPL  2020-05-26       316.73  31380450      323.50
# 4              AAPL  2020-05-22       318.89  20450750      315.77
# ...             ...         ...          ...       ...         ...
# 17523          TSLA  2019-12-21       405.59  14785210      410.29
# 17524          TSLA  2019-12-22       405.59  14785210      410.29
# 17525          TSLA  2019-12-25       425.25   8054720      418.36
# 17526          TSLA  2019-12-28       430.38   9956827      435.00
# 17527          TSLA  2019-12-29       430.38   9956827      435.00
#
#        high_value  low_value
# 0          321.15   316.4700
# 1          323.44   315.6300
# 2          318.71   313.0900
# 3          324.24   316.5000
# ...

# %%
Company_name
# Out:
#   ticker_symbol company_name
# 0          AAPL        apple
# 1          GOOG   Google Inc
# 2         GOOGL   Google Inc
# 3          AMZN   Amazon.com
# 4          TSLA    Tesla Inc
# 5          MSFT    Microsoft

# %% [markdown]
# # Data Cleaning
# this is a process in data analysis where you clean up your data set by  removing Null values, Removing Duplicates,
# changing inconsistency, dropping irrelevant values and and changing data types if not correct

# %%
Company_data.info() # this helps me to have an overview of my dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17528 entries, 0 to 17527
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ticker_symbol  17528 non-null  object
#  1   day_date       17528 non-null  object
#  2   close_value    17528 non-null  float64
#  3   volume         17528 non-null  int64
#  4   open_value     17528 non-null  float64
#  5   high_value     17528 non-null  float64
#  6   low_value      17528 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 958.7+ KB

# %%
Company_data.value_counts('ticker_symbol') # value counts helps me to know how many values i will be working with under ticker_symbol
# Out:
# ticker_symbol
# AAPL     3085
# AMZN     3085
# GOOGL    3085
# MSFT     3085
# TSLA     3065
# GOOG     2123
# Name: count, dtype: int64

# %%
Company_data.isnull().sum() # checked for Null values and found out that there are no missing values
# Out:
# ticker_symbol    0
# day_date         0
# close_value      0
# volume           0
# open_value       0
# high_value       0
# low_value        0
# dtype: int64

# %%
# converting the day_date values into a datetime
Company_data['day_date'] = pd.to_datetime(Company_data['day_date'])

# %%
Company_data
# Out:
#       ticker_symbol   day_date  close_value    volume  open_value  high_value  \
# 0              AAPL 2020-05-29       317.94  38399530      319.25      321.15
# 1              AAPL 2020-05-28       318.25  33449100      316.77      323.44
# 2              AAPL 2020-05-27       318.11  28236270      316.14      318.71
# 3              AAPL 2020-05-26       316.73  31380450      323.50      324.24
# 4              AAPL 2020-05-22       318.89  20450750      315.77      319.23
# ...             ...        ...          ...       ...         ...         ...
# 17523          TSLA 2019-12-21       405.59  14785210      410.29      413.00
# 17524          TSLA 2019-12-22       405.59  14785210      410.29      413.00
# 17525          TSLA 2019-12-25       425.25   8054720      418.36      425.47
# 17526          TSLA 2019-12-28       430.38   9956827      435.00      435.31
# 17527          TSLA 2019-12-29       430.38   9956827      435.00      435.31
#
#        low_value
# ...

# %%
Company_data['day'] =Company_data['day_date'].dt.day
Company_data['month'] = Company_data['day_date'].dt.month   # this format is to used to seperate the dates and allow them stay in different colums
Company_data['year'] = Company_data['day_date'].dt.year

# %%
Company_data
# Out:
#       ticker_symbol   day_date  close_value    volume  open_value  high_value  \
# 0              AAPL 2020-05-29       317.94  38399530      319.25      321.15
# 1              AAPL 2020-05-28       318.25  33449100      316.77      323.44
# 2              AAPL 2020-05-27       318.11  28236270      316.14      318.71
# 3              AAPL 2020-05-26       316.73  31380450      323.50      324.24
# 4              AAPL 2020-05-22       318.89  20450750      315.77      319.23
# ...             ...        ...          ...       ...         ...         ...
# 17523          TSLA 2019-12-21       405.59  14785210      410.29      413.00
# 17524          TSLA 2019-12-22       405.59  14785210      410.29      413.00
# 17525          TSLA 2019-12-25       425.25   8054720      418.36      425.47
# 17526          TSLA 2019-12-28       430.38   9956827      435.00      435.31
# 17527          TSLA 2019-12-29       430.38   9956827      435.00      435.31
#
# ...

# %% [markdown]
# ## Make a copy

# %%
Company_data2 = Company_data.copy()

# %% [markdown]
# ## Check for Duplicates

# %%
Company_data.duplicated().sum() # found No Duplicates
# Out:
# 0

# %%
Company_data.value_counts('day_date')
# Out:
# day_date
# 2016-01-22    6
# 2017-08-23    6
# 2017-06-14    6
# 2017-06-15    6
# 2017-06-16    6
#              ..
# 2010-06-23    4
# 2010-06-24    4
# 2010-06-25    4
# 2010-06-28    4
# 2010-06-01    4
# Name: count, Length: 3085, dtype: int64

# %%
Company_data.drop(columns = ['day_date'], inplace = True)

# %%
Data = pd.concat([Company_data, Company_name],axis=1)

# %%
Company_data
# Out:
#       ticker_symbol  close_value    volume  open_value  high_value  low_value  \
# 0              AAPL       317.94  38399530      319.25      321.15   316.4700
# 1              AAPL       318.25  33449100      316.77      323.44   315.6300
# 2              AAPL       318.11  28236270      316.14      318.71   313.0900
# 3              AAPL       316.73  31380450      323.50      324.24   316.5000
# 4              AAPL       318.89  20450750      315.77      319.23   315.3500
# ...             ...          ...       ...         ...         ...        ...
# 17523          TSLA       405.59  14785210      410.29      413.00   400.1850
# 17524          TSLA       405.59  14785210      410.29      413.00   400.1850
# 17525          TSLA       425.25   8054720      418.36      425.47   412.6875
# 17526          TSLA       430.38   9956827      435.00      435.31   426.1100
# 17527          TSLA       430.38   9956827      435.00      435.31   426.1100
#
#        day  month  year
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17528 entries, 0 to 17527
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ticker_symbol  17528 non-null  object
#  1   close_value    17528 non-null  float64
#  2   volume         17528 non-null  int64
#  3   open_value     17528 non-null  float64
#  4   high_value     17528 non-null  float64
#  5   low_value      17528 non-null  float64
#  6   day            17528 non-null  int32
#  7   month          17528 non-null  int32
#  8   year           17528 non-null  int32
#  9   ticker_symbol  6 non-null      object
#  10  company_name   6 non-null      object
# dtypes: float64(4), int32(3), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
Data
# Out:
#       ticker_symbol  close_value    volume  open_value  high_value  low_value  \
# 0              AAPL       317.94  38399530      319.25      321.15   316.4700
# 1              AAPL       318.25  33449100      316.77      323.44   315.6300
# 2              AAPL       318.11  28236270      316.14      318.71   313.0900
# 3              AAPL       316.73  31380450      323.50      324.24   316.5000
# 4              AAPL       318.89  20450750      315.77      319.23   315.3500
# ...             ...          ...       ...         ...         ...        ...
# 17523          TSLA       405.59  14785210      410.29      413.00   400.1850
# 17524          TSLA       405.59  14785210      410.29      413.00   400.1850
# 17525          TSLA       425.25   8054720      418.36      425.47   412.6875
# 17526          TSLA       430.38   9956827      435.00      435.31   426.1100
# 17527          TSLA       430.38   9956827      435.00      435.31   426.1100
#
# ...

# %%
Data.isnull().sum()
# Out:
# ticker_symbol        0
# close_value          0
# volume               0
# open_value           0
# high_value           0
# low_value            0
# day                  0
# month                0
# year                 0
# ticker_symbol    17522
# company_name     17522
# dtype: int64

# %%
# i realized that after i concatenated the both data set ticker_symbol and company_name had null values 
#i will be using the merge to solve the values mistakes 

Data = pd.merge(Company_data, Company_name, on="ticker_symbol", how="left") # on -Ensures the join is done correctly on this column
                                                                             # how =left - it Keeps all rows from Company_data and adds corresponding
                                                                                #company_name.

# %%
# Creating  a dictionary from available ticker-symbol mappings
ticker_mapping = Company_name.set_index("ticker_symbol")["company_name"].to_dict()

# %%
# Fill missing values in Data
Data["company_name"] = Data["ticker_symbol"].map(ticker_mapping) #this is where the magic is i filled it up using the mapping value to enable it correspond 
                                                                 # with our previous code which states is on=ticker_symbol and how=left

# %%
Data.isnull().sum() # now we no longer have missing values and the both ticker symbol has been joined together.
# Out:
# ticker_symbol    0
# close_value      0
# volume           0
# open_value       0
# high_value       0
# low_value        0
# day              0
# month            0
# year             0
# company_name     0
# dtype: int64

# %%
Data
# Out:
#       ticker_symbol  close_value    volume  open_value  high_value  low_value  \
# 0              AAPL       317.94  38399530      319.25      321.15   316.4700
# 1              AAPL       318.25  33449100      316.77      323.44   315.6300
# 2              AAPL       318.11  28236270      316.14      318.71   313.0900
# 3              AAPL       316.73  31380450      323.50      324.24   316.5000
# 4              AAPL       318.89  20450750      315.77      319.23   315.3500
# ...             ...          ...       ...         ...         ...        ...
# 17523          TSLA       405.59  14785210      410.29      413.00   400.1850
# 17524          TSLA       405.59  14785210      410.29      413.00   400.1850
# 17525          TSLA       425.25   8054720      418.36      425.47   412.6875
# 17526          TSLA       430.38   9956827      435.00      435.31   426.1100
# 17527          TSLA       430.38   9956827      435.00      435.31   426.1100
#
# ...

# %% [markdown]
# # DATA VISUALIZATION

# %%
import seaborn as sns  
sns.boxplot(data=Data[["company_name","close_value", "volume", "open_value", "high_value", "low_value"]]) #This enabled us Check for outliers 
                                                                                                        #(especially in close_value, volume, etc.)
# Out:
# <Axes: >

# %%
# removing the outliers by finding the limits of the outliers
#find the limits
upper_limit = Data['volume'].mean() +3*Data['volume'].std()
lower_limit = Data['volume'].mean() -3*Data['volume'].std()
print ('upper_limit:', upper_limit)
print ('lower_limit:', lower_limit)
# Out:
# upper_limit: 119936394.55682701
# lower_limit: -79427565.84824646

# %%
# find the outliers
Data.loc[(Data['volume'] >= upper_limit) | (Data['volume'] <= lower_limit)]
# Out:
#       ticker_symbol  close_value     volume  open_value  high_value  \
# 1092           AAPL        93.42  133059000      96.040     96.6289
# 1199           AAPL       103.12  161882500      94.870    108.8000
# 1200           AAPL       105.76  127246600     110.430    111.9000
# 1213           AAPL       114.64  123601900     117.420    117.7000
# 1343           AAPL       115.31  146184300     117.625    118.1200
# ...             ...          ...        ...         ...         ...
# 13987          MSFT        52.87  135152900      52.300     54.0700
# 14044          MSFT        51.78  126793100      51.910     52.4297
# 14045          MSFT        51.78  126793100      51.910     52.4297
# 14063          MSFT        49.83  133456500      49.810     50.9400
# 14064          MSFT        49.83  133456500      49.810     50.9400
#
#        low_value  day  month  year company_name
# 1092      93.340   27      1  2016        apple
# 1199      92.000   24      8  2015        apple
# ...

# %%
# after i found out my outliers i decided not to remove them instead i will use the capping method
# capping Helps change the outliers values to upper (or) lower limit values
Data3 = Data.copy()
Data.loc[(Data['volume'] > upper_limit),'volume'] = upper_limit
Data.loc[(Data['volume'] < lower_limit),'volume'] = lower_limit
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8024\3074481459.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '119936394.55682701' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   Data.loc[(Data['volume'] > upper_limit),'volume'] = upper_limit

# %%
sns.boxplot(data=Data["volume"])
# Out:
# <Axes: ylabel='volume'>

# %%
len(Data) #helps check
# Out:
# 17528

# %%
  
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.lineplot(data=Data, x="day", y="open_value", hue="ticker_symbol")
plt.title("Stock Opening Prices Over Time")
plt.xlabel("Day")
plt.ylabel("Opening_Value")
plt.legend(title="Ticker_symbol")
plt.show()

# %%
plt.figure(figsize=(12, 9))
sns.scatterplot(data=Data, x="day", y="close_value", hue="ticker_symbol")
plt.title("Stock Opening Prices Over Time")
plt.xlabel("Day")
plt.ylabel("Opening_Value")
plt.legend(title="Ticker_symbol")
plt.show()

# %%
#After i visualized my data set, I realized that my data points were overlapping each other that means the values were too close 
#so i decided to sample my data into seperate forms doing this i imported my numpy 
# Sample Data
import pandas as pd
import numpy as np

np.random.seed(42)
dates = pd.date_range(start="2019-01-01", periods=100) # i centralized the start date to be solely 2023 so i can see the visuals clearly
stocks = ["AAPL", "AMZN", "GOOGL", "GOOG", "MSFT", "TSLA"]
data = {"Date": np.tile(dates, len(stocks)), # the Len helps to return the number of dates and in this case we are using 100 as our periods
    "Stock": np.repeat(stocks, len(dates)), # the Len helps to return the number stock 6
    "Opening_Value": np.random.randint(500, 2500, len(dates) * len(stocks))} # so i calculated the the total number of date * stock  100*6= 600

# %%
df = pd.DataFrame(Data)

# %%
print(df.head())  # Check first few rows
print(df.columns)  # Check column names
# Out:
#   ticker_symbol  close_value      volume  open_value  high_value  low_value  \
# 0          AAPL       317.94  38399530.0      319.25      321.15     316.47
# 1          AAPL       318.25  33449100.0      316.77      323.44     315.63
# 2          AAPL       318.11  28236270.0      316.14      318.71     313.09
# 3          AAPL       316.73  31380450.0      323.50      324.24     316.50
# 4          AAPL       318.89  20450750.0      315.77      319.23     315.35
#
#    day  month  year company_name
# 0   29      5  2020        apple
# 1   28      5  2020        apple
# 2   27      5  2020        apple
# 3   26      5  2020        apple
# 4   22      5  2020        apple
# Index(['ticker_symbol', 'close_value', 'volume', 'open_value', 'high_value',
#        'low_value', 'day', 'month', 'year', 'company_name'],
#       dtype='object')

# %%
Company_data
# Out:
#       ticker_symbol  close_value    volume  open_value  high_value  low_value  \
# 0              AAPL       317.94  38399530      319.25      321.15   316.4700
# 1              AAPL       318.25  33449100      316.77      323.44   315.6300
# 2              AAPL       318.11  28236270      316.14      318.71   313.0900
# 3              AAPL       316.73  31380450      323.50      324.24   316.5000
# 4              AAPL       318.89  20450750      315.77      319.23   315.3500
# ...             ...          ...       ...         ...         ...        ...
# 17523          TSLA       405.59  14785210      410.29      413.00   400.1850
# 17524          TSLA       405.59  14785210      410.29      413.00   400.1850
# 17525          TSLA       425.25   8054720      418.36      425.47   412.6875
# 17526          TSLA       430.38   9956827      435.00      435.31   426.1100
# 17527          TSLA       430.38   9956827      435.00      435.31   426.1100
#
#        day  month  year
# ...

# %%
Data.isnull().sum()
# Out:
# ticker_symbol    0
# close_value      0
# volume           0
# open_value       0
# high_value       0
# low_value        0
# day              0
# month            0
# year             0
# company_name     0
# dtype: int64

# %%
df['year'] = pd.to_numeric(df['year'], errors='coerce')

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
dates = pd.date_range(end="2020-01-01",periods=100) # i centralized the start date to be solely 2020 so i can see the visuals clearly
stocks = ["AAPL", "AMZN", "GOOGL", "GOOG", "MSFT", "TSLA"]
data2 = {"Date": np.tile(dates, len(stocks)), # the Len helps to return the number of dates and in this case we are using 100 as our periods
    "Stock": np.repeat(stocks, len(dates)), # the Len helps to return the number stock 6
    "Closing_Value": np.random.randint(500, 2500, len(dates) * len(stocks))} # so i calculated the the total number of date * stock  100*6= 600

# %%
dfe = pd.DataFrame(data2)

# %%
dfe
# Out:
#           Date Stock  Closing_Value
# 0   2019-09-24  AAPL           1626
# 1   2019-09-25  AAPL           1959
# 2   2019-09-26  AAPL           1360
# 3   2019-09-27  AAPL           1794
# 4   2019-09-28  AAPL           1630
# ..         ...   ...            ...
# 595 2019-12-28  TSLA            768
# 596 2019-12-29  TSLA            869
# 597 2019-12-30  TSLA           1135
# 598 2019-12-31  TSLA           1629
# 599 2020-01-01  TSLA           2193
#
# [600 rows x 3 columns]

# %%
df
# Out:
#       ticker_symbol  close_value      volume  open_value  high_value  \
# 0              AAPL       317.94  38399530.0      319.25      321.15
# 1              AAPL       318.25  33449100.0      316.77      323.44
# 2              AAPL       318.11  28236270.0      316.14      318.71
# 3              AAPL       316.73  31380450.0      323.50      324.24
# 4              AAPL       318.89  20450750.0      315.77      319.23
# ...             ...          ...         ...         ...         ...
# 17523          TSLA       405.59  14785210.0      410.29      413.00
# 17524          TSLA       405.59  14785210.0      410.29      413.00
# 17525          TSLA       425.25   8054720.0      418.36      425.47
# 17526          TSLA       430.38   9956827.0      435.00      435.31
# 17527          TSLA       430.38   9956827.0      435.00      435.31
#
#        low_value  day  month  year company_name
# 0       316.4700   29      5  2020        apple
# ...

# %%
# Trying to identify Trends Overtime
import matplotlib.pyplot as plt  
dfe[dfe['Stock'].isin(['AAPL', 'TSLA'])].groupby(['Date', 'Stock'])['Closing_Value'].mean().unstack().plot(figsize=(12,6))
plt.title("Stock Closing Prices Over Time")
plt.ylabel("Closing Value")         # The Trend over time between AAPL and TSLA stock is that their Closing values is thesame with their opening value 
                                    # it often spike up and drop suddenly,
                                    # meaning they are not stable over time.
plt.show()

# %%
dfe['Moving_Avg'] = dfe.groupby('Stock')['Closing_Value'].transform(lambda x: x.rolling(5, min_periods=1).mean())

dfe[dfe['Stock'].isin(['AAPL', 'TSLA'])].groupby(['Date', 'Stock'])['Moving_Avg'].mean().unstack().plot(figsize=(12,6))
plt.title("Stock Closing Prices Over Time (Smoothed)")
plt.ylabel("Closing Value (Moving Avg)")
plt.show()             # this plot shows my trends in a more smooter way to enable me analize the trends without it being too clusttered (case study Apple and Tesla

# %%
volatility = dfe.groupby("Stock")["Closing_Value"].std()
print(volatility)         # This helps me determine which stock has the highest price fluctuation (volatility).
                       # The result shows that GOOG has the highest volatility at approximately 618.92,
                        # meaning it experiences the largest price changes over time.
# Out:
# Stock
# AAPL     546.202173
# AMZN     581.554748
# GOOG     618.916872
# GOOGL    515.075935
# MSFT     564.107581
# TSLA     556.047857
# Name: Closing_Value, dtype: float64

# %%
volume_by_stock = Data.groupby('ticker_symbol')['volume'].sum().sort_values(ascending=False)
print(volume_by_stock)          # This helps me determine which stock has the Highest Trading Volume.
                                  # The result shows that AAPL  has the highest Trading Volume.
# Out:
# ticker_symbol
# AAPL     1.762687e+11
# MSFT     1.156120e+11
# TSLA     1.864232e+10
# AMZN     1.360412e+10
# GOOGL    6.612138e+09
# GOOG     3.761314e+09
# Name: volume, dtype: float64

# %%
plt.figure(figsize=(12,6))
for stock in ['AAPL', 'TSLA', 'GOOG']:  
    stock_data = Data [Data['ticker_symbol'] == stock]
    plt.plot(stock_data['volume'], label=stock)

plt.title("Stock Trading Volume Over Time")
plt.xlabel("Time")
plt.ylabel("Volume")
plt.legend()
plt.show()

# %%
# I wanted to get my Daily return %

# Ensure close_value is numeric
Data['close_value'] = pd.to_numeric(Data['close_value'], errors='coerce')

# Calculate daily return as percentage change
Data['daily_return'] = Data['close_value'].pct_change() * 100

# Check if the column is added
print(Data.head())
# Out:
#   ticker_symbol  close_value      volume  open_value  high_value  low_value  \
# 0          AAPL       317.94  38399530.0      319.25      321.15     316.47
# 1          AAPL       318.25  33449100.0      316.77      323.44     315.63
# 2          AAPL       318.11  28236270.0      316.14      318.71     313.09
# 3          AAPL       316.73  31380450.0      323.50      324.24     316.50
# 4          AAPL       318.89  20450750.0      315.77      319.23     315.35
#
#    day  month  year company_name  daily_return
# 0   29      5  2020        apple           NaN
# 1   28      5  2020        apple      0.097503
# 2   27      5  2020        apple     -0.043991
# 3   26      5  2020        apple     -0.433812
# 4   22      5  2020        apple      0.681969

# %%
# i noticed there was a null value and i wouldnt want my data to look messy by dropping the first row 
# so i will fill the null values with Fillna 0
Data['daily_return'] = Data['daily_return'].fillna(0)

# %%
print(Data.head())
# Out:
#   ticker_symbol  close_value      volume  open_value  high_value  low_value  \
# 0          AAPL       317.94  38399530.0      319.25      321.15     316.47
# 1          AAPL       318.25  33449100.0      316.77      323.44     315.63
# 2          AAPL       318.11  28236270.0      316.14      318.71     313.09
# 3          AAPL       316.73  31380450.0      323.50      324.24     316.50
# 4          AAPL       318.89  20450750.0      315.77      319.23     315.35
#
#    day  month  year company_name  daily_return
# 0   29      5  2020        apple      0.000000
# 1   28      5  2020        apple      0.097503
# 2   27      5  2020        apple     -0.043991
# 3   26      5  2020        apple     -0.433812
# 4   22      5  2020        apple      0.681969

# %%
Data
# Out:
#       ticker_symbol  close_value      volume  open_value  high_value  \
# 0              AAPL       317.94  38399530.0      319.25      321.15
# 1              AAPL       318.25  33449100.0      316.77      323.44
# 2              AAPL       318.11  28236270.0      316.14      318.71
# 3              AAPL       316.73  31380450.0      323.50      324.24
# 4              AAPL       318.89  20450750.0      315.77      319.23
# ...             ...          ...         ...         ...         ...
# 17523          TSLA       405.59  14785210.0      410.29      413.00
# 17524          TSLA       405.59  14785210.0      410.29      413.00
# 17525          TSLA       425.25   8054720.0      418.36      425.47
# 17526          TSLA       430.38   9956827.0      435.00      435.31
# 17527          TSLA       430.38   9956827.0      435.00      435.31
#
#        low_value  day  month  year company_name  daily_return
# 0       316.4700   29      5  2020        apple      0.000000
# ...

# %%
import seaborn as sns

plt.figure(figsize=(8,6))
sns.scatterplot(x=Data['volume'], y=Data['daily_return'])
plt.xlabel("Trading Volume")
plt.ylabel("Daily Return (%)")                       # Key insights not all stocks that has High trading volume has a high return -8.0 and returned  0
                                                      # while the ones with a low trading volume had a high daily return started with -8.0 and returned 800
plt.title("Trading Volume vs. Daily Return")
plt.show()

# %%
print(Data.columns)
# Out:
# Index(['ticker_symbol', 'close_value', 'volume', 'open_value', 'high_value',
#        'low_value', 'day', 'month', 'year', 'company_name', 'daily_return'],
#       dtype='object')

# %%
Data2=Data.copy()

# %% [markdown]
# ## Data Modeling with Sklearn

# %% [raw]
# Since i am exploring market value and price movements, i will  apply predictive modeling techniques.
# Objectives:
# 1. I want to predict future stock prices
# 2. I want to classify stocks based on volatility or trading volume trends

# %% [markdown]
# # ENCODING
# Before i Proceed i will be encoding  my ticker_symbol and company_name because they are in object  and machine Learning Needs Numeric Values

# %%
# To enable me encode since i have many values i will have to put them in category and to achieve this i will need my dictionary
ticker_code = {'AAPL': 0, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 3,'AMZN':4, 'GOOG':5}

# %%
#Dropping columns
#The ticker symbol already represents the company name to avoid reindundancy
Data = Data.drop(columns=['company_name'])

# %%
Data['ticker_symbol'] = Data['ticker_symbol'].replace(ticker_code)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8024\716374102.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Data['ticker_symbol'] = Data['ticker_symbol'].replace(ticker_code)

# %%
Data
# Out:
#        ticker_symbol  close_value      volume  open_value  high_value  \
# 0                  0       317.94  38399530.0      319.25      321.15
# 1                  0       318.25  33449100.0      316.77      323.44
# 2                  0       318.11  28236270.0      316.14      318.71
# 3                  0       316.73  31380450.0      323.50      324.24
# 4                  0       318.89  20450750.0      315.77      319.23
# ...              ...          ...         ...         ...         ...
# 17523              3       405.59  14785210.0      410.29      413.00
# 17524              3       405.59  14785210.0      410.29      413.00
# 17525              3       425.25   8054720.0      418.36      425.47
# 17526              3       430.38   9956827.0      435.00      435.31
# 17527              3       430.38   9956827.0      435.00      435.31
#
#        low_value  day  month  year  daily_return
# 0       316.4700   29      5  2020      0.000000
# ...

# %%
Data.columns
# Out:
# Index(['ticker_symbol', 'close_value', 'volume', 'open_value', 'high_value',
#        'low_value', 'day', 'month', 'year', 'daily_return'],
#       dtype='object')

# %%
print(Data['volume'].dtype)
# Out:
# float64

# %%
Data.value_counts('volume')
# Out:
# volume
# 1.199364e+08    410
# 2.790354e+06      6
# 1.637241e+06      4
# 3.811629e+07      4
# 3.217141e+07      4
#                ...
# 2.791803e+06      1
# 2.792124e+06      1
# 2.793759e+06      1
# 2.794228e+06      1
# 4.605293e+06      1
# Name: count, Length: 13705, dtype: int64

# %%
Data
# Out:
#        ticker_symbol  close_value      volume  open_value  high_value  \
# 0                  0       317.94  38399530.0      319.25      321.15
# 1                  0       318.25  33449100.0      316.77      323.44
# 2                  0       318.11  28236270.0      316.14      318.71
# 3                  0       316.73  31380450.0      323.50      324.24
# 4                  0       318.89  20450750.0      315.77      319.23
# ...              ...          ...         ...         ...         ...
# 17523              3       405.59  14785210.0      410.29      413.00
# 17524              3       405.59  14785210.0      410.29      413.00
# 17525              3       425.25   8054720.0      418.36      425.47
# 17526              3       430.38   9956827.0      435.00      435.31
# 17527              3       430.38   9956827.0      435.00      435.31
#
#        low_value  day  month  year  daily_return
# 0       316.4700   29      5  2020      0.000000
# ...

# %%
Data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17523    False
# 17524    False
# 17525    False
# 17526    False
# 17527    False
# Length: 17528, dtype: bool

# %%
Data.duplicated().sum()
# Out:
# 0

# %%
print(Data.head())
# Out:
#    ticker_symbol  close_value      volume  open_value  high_value  low_value  \
# 0              0       317.94  38399530.0      319.25      321.15     316.47
# 1              0       318.25  33449100.0      316.77      323.44     315.63
# 2              0       318.11  28236270.0      316.14      318.71     313.09
# 3              0       316.73  31380450.0      323.50      324.24     316.50
# 4              0       318.89  20450750.0      315.77      319.23     315.35
#
#    day  month  year  daily_return
# 0   29      5  2020      0.000000
# 1   28      5  2020      0.097503
# 2   27      5  2020     -0.043991
# 3   26      5  2020     -0.433812
# 4   22      5  2020      0.681969

# %%
Data.value_counts('ticker_symbol')
# Out:
# ticker_symbol
# 0    3085
# 1    3085
# 2    3085
# 4    3085
# 3    3065
# 5    2123
# Name: count, dtype: int64

# %%
Data['ticker_symbol'].unique()
# Out:
# array([0, 4, 1, 5, 2, 3], dtype=int64)

# %%
Data['ticker_symbol'].isnull().sum()
# Out:
# 0

# %%
Data.describe()
# Out:
#        ticker_symbol   close_value        volume    open_value    high_value  \
# count   17528.000000  17528.000000  1.752800e+04  17528.000000  17528.000000
# mean        2.362220    455.167040  1.908379e+07    455.314451    459.710597
# std         1.648616    469.324583  2.747197e+07    469.588291    473.771691
# min         0.000000     15.800000  7.932000e+03     16.140000     16.630000
# 25%         1.000000    100.300000  2.075086e+06     99.883750    100.927500
# 50%         2.000000    256.500000  4.835618e+06    256.095000    259.604500
# 75%         4.000000    735.630000  2.704358e+07    735.740000    742.000000
# max         5.000000   2497.940000  1.199364e+08   2500.000000   2525.450000
#
#           low_value           day         month          year  daily_return
# count  17528.000000  17528.000000  17528.000000  17528.000000  17528.000000
# mean     450.466694     15.732257      6.524646   2015.489617      0.125521
# ...

# %% [markdown]
# # Split Train_test model

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

sc = StandardScaler()
Data['daily_return'] = sc.fit_transform(np.array(Data['daily_return']).reshape(-1,1)) #

# %%
x =Data.drop(['volume'],axis = 1)
y= Data['volume']

# %%
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=30)

# %%
x_test
# Out:
#        ticker_symbol  close_value  open_value  high_value  low_value  day  \
# 8966               1     958.6200    957.9100    959.9500   948.7000   17
# 6120               4    1964.5200   1991.2100   1996.0000  1962.2255   21
# 2112               0      59.7186     59.2786     59.7928    58.9528    5
# 4829               4     272.0880    272.3000    273.4700   269.0000   25
# 13066              2      33.0300     32.7700     33.0700    32.5050   13
# ...              ...          ...         ...         ...        ...  ...
# 16886              3      20.2400     20.2000     20.2829    20.0300   12
# 889                0     105.7100    107.7100    107.8090   104.0800   14
# 4201               4     664.5100    668.5000    669.9000   658.9300   21
# 4245               4     573.1500    570.7600    579.0000   567.3800   19
# 10093              5     802.3200    814.6600    815.8400   799.8000   30
#
#        month  year  daily_return
# 8966       6  2017     -0.137091
# ...

# %%
y_test
# Out:
# 8966      2545774.0
# 6120      3185612.0
# 2112     67606475.0
# 4829      2447760.0
# 13066    40896510.0
#             ...
# 16886      243912.0
# 889      50901380.0
# 4201      3219507.0
# 4245      4342881.0
# 10093     3243568.0
# Name: volume, Length: 5259, dtype: float64

# %%
x_train
# Out:
#        ticker_symbol  close_value  open_value  high_value  low_value  day  \
# 17271              3     341.1000    341.8600    344.6800   338.6010   30
# 128                0     261.7800    262.5900    263.1800   260.8400   22
# 1932               0     100.0135    100.3443    100.7243    99.9088   21
# 3855               4     949.0400    940.9500    949.0500   939.2100    8
# 1679               0      69.4600     69.4286     69.7943    69.1286   26
# ...              ...          ...         ...         ...        ...  ...
# 500                0     191.8300    191.6350    193.4200   191.3500    4
# 12077              2      72.4000     73.5800     73.8700    72.4000   17
# 15277              3     251.2100    247.9100    251.7000   247.5100    6
# 4517               4     331.3200    327.6000    332.7559   325.5700   19
# 5925               4    1125.3500   1126.1000   1131.7500  1124.0600   11
#
#        month  year  daily_return
# 17271      9  2017     -0.310686
# ...

# %%
x_train.describe()
# Out:
#        ticker_symbol   close_value    open_value    high_value     low_value  \
# count   12269.000000  12269.000000  12269.000000  12269.000000  12269.000000
# mean        2.364007    457.380202    457.522341    461.920969    452.628326
# std         1.648782    471.256460    471.573364    475.673445    466.672961
# min         0.000000     15.800000     16.140000     16.630000     14.980000
# 25%         1.000000    100.790000    100.480000    101.530000     99.500000
# 50%         2.000000    257.130000    257.330000    260.350000    253.000000
# 75%         4.000000    739.310000    741.000000    745.750000    734.640000
# max         5.000000   2497.940000   2500.000000   2525.450000   2467.270000
#
#                 day         month          year  daily_return
# count  12269.000000  12269.000000  12269.000000  12269.000000
# mean      15.729481      6.522292   2015.502975     -0.003372
# std        8.751688      3.437612      2.752228      0.866122
# ...

# %%
y_train # i discovered that my y_train is in float value which is not a continious value 
            # so i will try encoding it again to Convert y_train into Categories
# Out:
# 17271    5.099051e+06
# 128      1.633126e+07
# 1932     1.199364e+08
# 3855     3.406954e+06
# 1679     5.905079e+07
#              ...
# 500      2.619062e+07
# 12077    2.245013e+07
# 15277    3.353601e+06
# 4517     6.886162e+06
# 5925     2.178670e+06
# Name: volume, Length: 12269, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_train = le.fit_transform(y_train)

# %%
y_train
# Out:
# array([ 5270,  6654, 10049, ...,  4080,  5875,  2733], dtype=int64)

# %%
print(y_train[:5])  # Print first 5 elements
print(np.isnan(y_train).sum())  # Count NaN values in NumPy array
# Out:
# [ 5270  6654 10049  4136  9288]
# 0

# %%
print(y_train.shape)  # See the size of y_train
# Out:
# (12269,)

# %%
Data
# Out:
#        ticker_symbol  close_value      volume  open_value  high_value  \
# 0                  0       317.94  38399530.0      319.25      321.15
# 1                  0       318.25  33449100.0      316.77      323.44
# 2                  0       318.11  28236270.0      316.14      318.71
# 3                  0       316.73  31380450.0      323.50      324.24
# 4                  0       318.89  20450750.0      315.77      319.23
# ...              ...          ...         ...         ...         ...
# 17523              3       405.59  14785210.0      410.29      413.00
# 17524              3       405.59  14785210.0      410.29      413.00
# 17525              3       425.25   8054720.0      418.36      425.47
# 17526              3       430.38   9956827.0      435.00      435.31
# 17527              3       430.38   9956827.0      435.00      435.31
#
#        low_value  day  month  year  daily_return
# 0       316.4700   29      5  2020     -0.013126
# ...

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)           # Since is a Regression we imported our Linear Regression
# Out:
# LinearRegression()

# %%
computer_prediction = model.predict(x_test) # this will help the computer make prediction

# %%
computer_prediction
# Out:
# array([4090.4398816 , -242.55233922, 6927.54559071, ..., 3292.45993011,
#        3714.70636934, 2982.67681345])

# %%
import numpy as np

# %%
np.array(y_test)
# Out:
# array([ 2545774.,  3185612., 67606475., ...,  3219507.,  4342881.,
#         3243568.])

# %%
print("Test data shape before prediction:", x_test.shape)
predictions = model.predict(x_test)
# Out:
# Test data shape before prediction: (5259, 9)

# %%
print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)
predictions = model.predict(x_test)
# Out:
# Train shape: (12269, 9)
# Test shape: (5259, 9)

# %% [markdown]
# # model evaluation

# %%
from sklearn.metrics import r2_score

# %%
R3 = r2_score(computer_prediction,y_test)

# %%
R3
# Out:
# -284030379.7212312

# %%
from sklearn.metrics import mean_squared_error, r2_score
MSE = mean_squared_error(computer_prediction,y_test)

# %%
MSE
# Out:
# 1110645650784190.4

# %%
from sklearn.metrics import mean_absolute_error
MSE = mean_absolute_error(computer_prediction,y_test)

# %%
MSE
# Out:
# 19053261.832451563

# %%
print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)
# Out:
# Train shape: (12269, 9)
# Test shape: (5259, 9)

# %%
print("Model input shape:", model.coef_.shape)
# Out:
# Model input shape: (9,)

# %%
print("Train features:", list(x_train.columns))
print("Test features:", list(x_test.columns))
# Out:
# Train features: ['ticker_symbol', 'close_value', 'open_value', 'high_value', 'low_value', 'day', 'month', 'year', 'daily_return']
# Test features: ['ticker_symbol', 'close_value', 'open_value', 'high_value', 'low_value', 'day', 'month', 'year', 'daily_return']

# %% [markdown]
# ## Model Dump

# %%
import joblib

joblib.dump(model, 'Stockmarket_model_Lr.model')
# Out:
# ['Stockmarket_model_Lr.model']

# %%
Data.describe()
# Out:
#        ticker_symbol   close_value        volume    open_value    high_value  \
# count   17528.000000  17528.000000  1.752800e+04  17528.000000  17528.000000
# mean        2.362220    455.167040  1.908379e+07    455.314451    459.710597
# std         1.648616    469.324583  2.747197e+07    469.588291    473.771691
# min         0.000000     15.800000  7.932000e+03     16.140000     16.630000
# 25%         1.000000    100.300000  2.075086e+06     99.883750    100.927500
# 50%         2.000000    256.500000  4.835618e+06    256.095000    259.604500
# 75%         4.000000    735.630000  2.704358e+07    735.740000    742.000000
# max         5.000000   2497.940000  1.199364e+08   2500.000000   2525.450000
#
#           low_value           day         month          year  daily_return
# count  17528.000000  17528.000000  17528.000000  17528.000000  1.752800e+04
# mean     450.466694     15.732257      6.524646   2015.489617  5.675261e-18
# ...
